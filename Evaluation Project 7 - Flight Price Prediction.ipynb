# %% [markdown]
# # Evaluation Project 7 - Flight Price Prediction

# %% [markdown]
# ## Importing necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from scipy.stats import zscore
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split as TTS
from sklearn.decomposition import PCA
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import Ridge,Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from sklearn import metrics
from sklearn.model_selection import GridSearchCV
import joblib

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading the dataset

# %%
df = pd.read_excel('Data_Train.xlsx')
df.head(20)
# Out:
#               Airline Date_of_Journey    Source Destination  \
# 0              IndiGo      24/03/2019  Banglore   New Delhi
# 1           Air India       1/05/2019   Kolkata    Banglore
# 2         Jet Airways       9/06/2019     Delhi      Cochin
# 3              IndiGo      12/05/2019   Kolkata    Banglore
# 4              IndiGo      01/03/2019  Banglore   New Delhi
# 5            SpiceJet      24/06/2019   Kolkata    Banglore
# 6         Jet Airways      12/03/2019  Banglore   New Delhi
# 7         Jet Airways      01/03/2019  Banglore   New Delhi
# 8         Jet Airways      12/03/2019  Banglore   New Delhi
# 9   Multiple carriers      27/05/2019     Delhi      Cochin
# 10          Air India       1/06/2019     Delhi      Cochin
# 11             IndiGo      18/04/2019   Kolkata    Banglore
# 12          Air India      24/06/2019   Chennai     Kolkata
# 13        Jet Airways       9/05/2019   Kolkata    Banglore
# 14             IndiGo      24/04/2019   Kolkata    Banglore
# 15          Air India       3/03/2019     Delhi      Cochin
# 16           SpiceJet      15/04/2019     Delhi      Cochin
# 17        Jet Airways      12/06/2019     Delhi      Cochin
# 18          Air India      12/06/2019     Delhi      Cochin
# 19        Jet Airways      27/05/2019     Delhi      Cochin
#
#                     Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0               BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1   CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2   DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3         CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4         BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# 5               CCU → BLR    09:00         11:25   2h 25m    non-stop
# 6         BLR → BOM → DEL    18:55  10:25 13 Mar  15h 30m      1 stop
# 7         BLR → BOM → DEL    08:00  05:05 02 Mar   21h 5m      1 stop
# 8         BLR → BOM → DEL    08:55  10:25 13 Mar  25h 30m      1 stop
# 9         DEL → BOM → COK    11:25         19:15   7h 50m      1 stop
# 10        DEL → BLR → COK    09:45         23:00  13h 15m      1 stop
# 11              CCU → BLR    20:20         22:55   2h 35m    non-stop
# 12              MAA → CCU    11:40         13:55   2h 15m    non-stop
# 13        CCU → BOM → BLR    21:10  09:20 10 May  12h 10m      1 stop
# 14              CCU → BLR    17:15         19:50   2h 35m    non-stop
# 15  DEL → AMD → BOM → COK    16:40  19:15 04 Mar  26h 35m     2 stops
# 16        DEL → PNQ → COK    08:45         13:15   4h 30m      1 stop
# 17        DEL → BOM → COK    14:00  12:35 13 Jun  22h 35m      1 stop
# 18  DEL → CCU → BOM → COK    20:15  19:15 13 Jun      23h     2 stops
# 19        DEL → BOM → COK    16:00  12:35 28 May  20h 35m      1 stop
#
#                 Additional_Info  Price
# 0                       No info   3897
# 1                       No info   7662
# 2                       No info  13882
# 3                       No info   6218
# 4                       No info  13302
# 5                       No info   3873
# 6   In-flight meal not included  11087
# 7                       No info  22270
# 8   In-flight meal not included  11087
# 9                       No info   8625
# 10                      No info   8907
# 11                      No info   4174
# 12                      No info   4667
# 13  In-flight meal not included   9663
# 14                      No info   4804
# 15                      No info  14011
# 16                      No info   5830
# 17  In-flight meal not included  10262
# 18                      No info  13381
# 19  In-flight meal not included  12898

# %%
df.tail(20)
# Out:
#                  Airline Date_of_Journey    Source Destination  \
# 10663        Jet Airways       6/06/2019     Delhi      Cochin
# 10664             IndiGo       9/04/2019  Banglore       Delhi
# 10665             IndiGo      27/04/2019   Kolkata    Banglore
# 10666        Jet Airways      12/06/2019     Delhi      Cochin
# 10667        Jet Airways      12/03/2019  Banglore   New Delhi
# 10668        Jet Airways       9/05/2019     Delhi      Cochin
# 10669          Air India      15/06/2019     Delhi      Cochin
# 10670          Air India      12/05/2019   Kolkata    Banglore
# 10671          Air India       6/06/2019    Mumbai   Hyderabad
# 10672        Jet Airways      27/06/2019     Delhi      Cochin
# 10673        Jet Airways      27/05/2019     Delhi      Cochin
# 10674        Jet Airways      12/03/2019  Banglore   New Delhi
# 10675          Air India       9/06/2019    Mumbai   Hyderabad
# 10676  Multiple carriers       1/05/2019     Delhi      Cochin
# 10677           SpiceJet      21/05/2019  Banglore       Delhi
# 10678           Air Asia       9/04/2019   Kolkata    Banglore
# 10679          Air India      27/04/2019   Kolkata    Banglore
# 10680        Jet Airways      27/04/2019  Banglore       Delhi
# 10681            Vistara      01/03/2019  Banglore   New Delhi
# 10682          Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 10663  DEL → JAI → BOM → COK    19:30  12:35 07 Jun   17h 5m     2 stops
# 10664              BLR → DEL    18:55         21:50   2h 55m    non-stop
# 10665              CCU → BLR    15:15         17:45   2h 30m    non-stop
# 10666        DEL → BOM → COK    18:15  19:00 13 Jun  24h 45m      1 stop
# 10667        BLR → BOM → DEL    22:55  20:20 13 Mar  21h 25m      1 stop
# 10668  DEL → JDH → BOM → COK    11:40         19:00   7h 20m     2 stops
# 10669        DEL → BOM → COK    08:00         19:15  11h 15m      1 stop
# 10670  CCU → IXR → DEL → BLR    05:50         23:15  17h 25m     2 stops
# 10671              BOM → HYD    21:05         22:25   1h 20m    non-stop
# 10672  DEL → AMD → BOM → COK    23:05  19:00 28 Jun  19h 55m     2 stops
# 10673  DEL → AMD → BOM → COK    13:25  04:25 28 May      15h     2 stops
# 10674        BLR → BOM → DEL    20:35  21:20 13 Mar  24h 45m      1 stop
# 10675              BOM → HYD    06:20         07:40   1h 20m    non-stop
# 10676        DEL → BOM → COK    10:20         19:00   8h 40m      1 stop
# 10677              BLR → DEL    05:55         08:35   2h 40m    non-stop
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#                     Additional_Info  Price
# 10663   In-flight meal not included  11733
# 10664                       No info   4823
# 10665                       No info   4804
# 10666   In-flight meal not included  10262
# 10667   In-flight meal not included  11087
# 10668                       No info  21219
# 10669                       No info   9929
# 10670                       No info  11411
# 10671                       No info   3100
# 10672   In-flight meal not included  11150
# 10673                       No info  16704
# 10674   In-flight meal not included  11087
# 10675                       No info   3100
# 10676                       No info   9794
# 10677  No check-in baggage included   3257
# 10678                       No info   4107
# 10679                       No info   4145
# 10680                       No info   7229
# 10681                       No info  12648
# 10682                       No info  11753

# %%
df.shape
# Out:
# (10683, 11)

# %% [markdown]
# ## Dataframe Description

# %% [markdown]
# Flight ticket prices can be something hard to guess, today we might see a price, check out the price of the same flight tomorrow, it will be a different story. We might have often heard travellers saying that flight ticket prices are so unpredictable. Here you will be provided with prices of flight tickets for various airlines between the months of March and June of 2019 and between various cities.
#
# **FEATURES:**
# - Airline: The name of the airline.
# - Date_of_Journey: The date of the journey
# - Source: The source from which the service begins.
# - Destination: The destination where the service ends.
# - Route: The route taken by the flight to reach the destination.
# - Dep_Time: The time when the journey starts from the source.
# - Arrival_Time: Time of arrival at the destination.
# - Duration: Total duration of the flight.
# - Total_Stops: Total stops between the source and destination.
# - Additional_Info: Additional information about the flight
#
# **TARGET**
# - Price: The price of the ticket
#
# **Task:** You have to use your skills as a data scientist and build a machine learning model to predict the price of the flight ticket.

# %% [markdown]
# ## EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %% [markdown]
# - `there are a very few null cells in the dataset`
# - `all features are object data types`
# - `target - price of the flight ticket is int64`

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df.nunique()
# Out:
# Airline              12
# Date_of_Journey      44
# Source                5
# Destination           6
# Route               128
# Dep_Time            222
# Arrival_Time       1343
# Duration            368
# Total_Stops           5
# Additional_Info      10
# Price              1870
# dtype: int64

# %% [markdown]
# ## Feature Extraction (pre-processing)

# %%
df['Date_of_Journey'] = pd.to_datetime(df['Date_of_Journey'])

# %%
df['Dep_Time'] = pd.to_datetime(df['Dep_Time'])

# %%
df['Arrival_Time']=pd.to_datetime(df['Arrival_Time'])

# %%
df['Journey_Day'] = pd.to_datetime(df.Date_of_Journey,format="%d/%m/%Y").dt.day
df['Journey_Month'] = pd.to_datetime(df.Date_of_Journey, format="%d/%m/%Y").dt.month

# %%
df.dtypes
# Out:
# Airline                    object
# Date_of_Journey    datetime64[ns]
# Source                     object
# Destination                object
# Route                      object
# Dep_Time           datetime64[ns]
# Arrival_Time       datetime64[ns]
# Duration                   object
# Total_Stops                object
# Additional_Info            object
# Price                       int64
# Journey_Day                 int64
# Journey_Month               int64
# dtype: object

# %% [markdown]
# - `columns containing date and time information has been converted to datetime64 data type, as it was object before.`
# - `converting date of journey into day and month, considering all dates pertain to the year 2019.`
# - `now we can drop Date_of_Journey column, since we have already separated date and month from it.`

# %%
df.drop("Date_of_Journey",axis=1,inplace=True)

# %%
df['Duration']=df['Duration'].str.replace('h','*60').str.replace(' ','+').str.replace('m','*1').apply(eval)
df['Duration']=pd.to_numeric(df['Duration'])

# %%
df['Dep_Hour']=pd.to_datetime(df['Dep_Time']).dt.hour
df['Dep_Min']=pd.to_datetime(df['Dep_Time']).dt.minute

# %% [markdown]
# - `duration of flight has been transformed into hours and minutes, and converted to numeric data for the purpose of model building`
# - `hours and minutes have been extracted from Dep_Time and stored in relevant columns accordingly`
# - `now we can drop Dep_Time, since we have alreayd stored the relevant info.`

# %%
df.drop("Dep_Time",axis=1,inplace=True)

# %%
df['Arrival_Hour']=pd.to_datetime(df['Arrival_Time']).dt.hour
df['Arrival_Min']=pd.to_datetime(df['Arrival_Time']).dt.minute
df.drop("Arrival_Time",axis=1,inplace=True)

# %% [markdown]
# - `similarly, Arrival_Time has been transformed into hours and minutes, and the extracted information has been stored in relevant columns. Also, Arrival_Time has been dropped accordingly.`

# %%
df.shape
# Out:
# (10683, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Source           10683 non-null  object
#  2   Destination      10683 non-null  object
#  3   Route            10682 non-null  object
#  4   Duration         10683 non-null  int64
#  5   Total_Stops      10682 non-null  object
#  6   Additional_Info  10683 non-null  object
#  7   Price            10683 non-null  int64
#  8   Journey_Day      10683 non-null  int64
#  9   Journey_Month    10683 non-null  int64
#  10  Dep_Hour         10683 non-null  int64
#  11  Dep_Min          10683 non-null  int64
#  12  Arrival_Hour     10683 non-null  int64
#  13  Arrival_Min      10683 non-null  int64
# dtypes: int64(8), object(6)
# memory usage: 1.1+ MB

# %%
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: Airline, dtype: int64
#
#
# Delhi       4537
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: Source, dtype: int64
#
#
# Cochin       4537
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: Destination, dtype: int64
#
#
# DEL → BOM → COK    2376
# BLR → DEL          1552
# CCU → BOM → BLR     979
# CCU → BLR           724
# BOM → HYD           621
#                    ...
# BOM → GOI → HYD       1
# CCU → IXA → BLR       1
# BOM → NDC → HYD       1
# CCU → VTZ → BLR       1
# BOM → CCU → HYD       1
# Name: Route, Length: 128, dtype: int64
#
#
# 170     550
# 90      386
# 165     337
# 175     337
# 155     329
#        ...
# 1780      1
# 2565      1
# 2525      1
# 1750      1
# 1975      1
# Name: Duration, Length: 368, dtype: int64
#
#
# 1 stop      5625
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: Total_Stops, dtype: int64
#
#
# No info                         8345
# In-flight meal not included     1982
# No check-in baggage included     320
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# No Info                            3
# 2 Long layover                     1
# 1 Short layover                    1
# Red-eye flight                     1
# Name: Additional_Info, dtype: int64
#
#
# 10262    258
# 10844    212
# 7229     162
# 4804     160
# 4823     131
#         ...
# 16946      1
# 10783      1
# 14861      1
# 10759      1
# 4098       1
# Name: Price, Length: 1870, dtype: int64
#
#
# 6     2166
# 5     1392
# 3     1361
# 27    1130
# 21    1111
# 24    1052
# 15     984
# 18     832
# 4      655
# Name: Journey_Day, dtype: int64
#
#
# 6     2536
# 3     2211
# 5     2074
# 9     1406
# 1     1075
# 12     957
# 4      424
# Name: Journey_Month, dtype: int64
#
#
# 9     916
# 7     867
# 8     697
# 17    695
# 6     687
# 20    651
# 5     629
# 11    580
# 19    567
# 10    536
# 14    523
# 21    492
# 16    472
# 18    444
# 13    417
# 22    387
# 15    319
# 2     194
# 12    178
# 4     170
# 23    161
# 0      40
# 1      37
# 3      24
# Name: Dep_Hour, dtype: int64
#
#
# 0     2062
# 30    1215
# 55    1058
# 10     890
# 45     876
# 5      773
# 15     692
# 25     691
# 20     666
# 35     665
# 50     591
# 40     504
# Name: Dep_Min, dtype: int64
#
#
# 19    1626
# 12     897
# 4      838
# 21     703
# 22     647
# 1      529
# 18     514
# 9      490
# 23     485
# 10     476
# 8      471
# 7      417
# 20     377
# 16     370
# 0      322
# 13     308
# 11     298
# 14     295
# 17     191
# 15     182
# 2       79
# 5       69
# 6       52
# 3       47
# Name: Arrival_Hour, dtype: int64
#
#
# 0     1447
# 25    1302
# 15    1286
# 35    1111
# 20     902
# 30     832
# 50     750
# 45     697
# 5      660
# 40     629
# 10     577
# 55     490
# Name: Arrival_Min, dtype: int64

# %% [markdown]
# - `Based on the unique values printed above for each column, we observe some repetitions`

# %%
df["Destination"] = df["Destination"].replace("New Delhi","Delhi")
df['Additional_Info'] = df['Additional_Info'].replace("No info", "No Info")

# %%
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: Airline, dtype: int64
#
#
# Delhi       4537
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: Source, dtype: int64
#
#
# Cochin       4537
# Banglore     2871
# Delhi        2197
# Hyderabad     697
# Kolkata       381
# Name: Destination, dtype: int64
#
#
# DEL → BOM → COK    2376
# BLR → DEL          1552
# CCU → BOM → BLR     979
# CCU → BLR           724
# BOM → HYD           621
#                    ...
# BOM → GOI → HYD       1
# CCU → IXA → BLR       1
# BOM → NDC → HYD       1
# CCU → VTZ → BLR       1
# BOM → CCU → HYD       1
# Name: Route, Length: 128, dtype: int64
#
#
# 170     550
# 90      386
# 165     337
# 175     337
# 155     329
#        ...
# 1780      1
# 2565      1
# 2525      1
# 1750      1
# 1975      1
# Name: Duration, Length: 368, dtype: int64
#
#
# 1 stop      5625
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: Total_Stops, dtype: int64
#
#
# No Info                         8348
# In-flight meal not included     1982
# No check-in baggage included     320
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# 2 Long layover                     1
# 1 Short layover                    1
# Red-eye flight                     1
# Name: Additional_Info, dtype: int64
#
#
# 10262    258
# 10844    212
# 7229     162
# 4804     160
# 4823     131
#         ...
# 16946      1
# 10783      1
# 14861      1
# 10759      1
# 4098       1
# Name: Price, Length: 1870, dtype: int64
#
#
# 6     2166
# 5     1392
# 3     1361
# 27    1130
# 21    1111
# 24    1052
# 15     984
# 18     832
# 4      655
# Name: Journey_Day, dtype: int64
#
#
# 6     2536
# 3     2211
# 5     2074
# 9     1406
# 1     1075
# 12     957
# 4      424
# Name: Journey_Month, dtype: int64
#
#
# 9     916
# 7     867
# 8     697
# 17    695
# 6     687
# 20    651
# 5     629
# 11    580
# 19    567
# 10    536
# 14    523
# 21    492
# 16    472
# 18    444
# 13    417
# 22    387
# 15    319
# 2     194
# 12    178
# 4     170
# 23    161
# 0      40
# 1      37
# 3      24
# Name: Dep_Hour, dtype: int64
#
#
# 0     2062
# 30    1215
# 55    1058
# 10     890
# 45     876
# 5      773
# 15     692
# 25     691
# 20     666
# 35     665
# 50     591
# 40     504
# Name: Dep_Min, dtype: int64
#
#
# 19    1626
# 12     897
# 4      838
# 21     703
# 22     647
# 1      529
# 18     514
# 9      490
# 23     485
# 10     476
# 8      471
# 7      417
# 20     377
# 16     370
# 0      322
# 13     308
# 11     298
# 14     295
# 17     191
# 15     182
# 2       79
# 5       69
# 6       52
# 3       47
# Name: Arrival_Hour, dtype: int64
#
#
# 0     1447
# 25    1302
# 15    1286
# 35    1111
# 20     902
# 30     832
# 50     750
# 45     697
# 5      660
# 40     629
# 10     577
# 55     490
# Name: Arrival_Min, dtype: int64

# %% [markdown]
# - `redundant repetitions have been removed`

# %%
df.nunique()
# Out:
# Airline              12
# Source                5
# Destination           5
# Route               128
# Duration            368
# Total_Stops           5
# Additional_Info       9
# Price              1870
# Journey_Day           9
# Journey_Month         7
# Dep_Hour             24
# Dep_Min              12
# Arrival_Hour         24
# Arrival_Min          12
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Airline            0
# Source             0
# Destination        0
# Route              1
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# Journey_Day        0
# Journey_Month      0
# Dep_Hour           0
# Dep_Min            0
# Arrival_Hour       0
# Arrival_Min        0
# dtype: int64

# %% [markdown]
# `There are 1 null values each in Route and Total_Stops, which can be filled using imputation techniques (MODE).`

# %%
df_null = df[df.isna().any(axis=1)]
df_null
# Out:
#         Airline Source Destination Route  Duration Total_Stops  \
# 9039  Air India  Delhi      Cochin   NaN      1420         NaN
#
#      Additional_Info  Price  Journey_Day  Journey_Month  Dep_Hour  Dep_Min  \
# 9039         No Info   7480            5              6         9       45
#
#       Arrival_Hour  Arrival_Min
# 9039             9           25

# %%
print(df["Route"].mode())
# Out:
# 0    DEL → BOM → COK
# dtype: object

# %%
print(df["Total_Stops"].mode())
# Out:
# 0    1 stop
# dtype: object

# %% [markdown]
# - `Since the row containing null values in both columns is the same, and the mode of route and total stops information coincides with source and destination information for the row, we can replace the information using fillna.`

# %%
df['Route'] = df['Route'].fillna(df['Route'].mode()[0])
df['Total_Stops']=df['Total_Stops'].fillna(df['Total_Stops'].mode()[0])

# %%
print(df.loc[[9039]])
# Out:
#         Airline Source Destination            Route  Duration Total_Stops  \
# 9039  Air India  Delhi      Cochin  DEL → BOM → COK      1420      1 stop
#
#      Additional_Info  Price  Journey_Day  Journey_Month  Dep_Hour  Dep_Min  \
# 9039         No Info   7480            5              6         9       45
#
#       Arrival_Hour  Arrival_Min
# 9039             9           25

# %% [markdown]
# `Null information has been filled`

# %%
df.isnull().sum()
# Out:
# Airline            0
# Source             0
# Destination        0
# Route              0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# Journey_Day        0
# Journey_Month      0
# Dep_Hour           0
# Dep_Min            0
# Arrival_Hour       0
# Arrival_Min        0
# dtype: int64

# %%
df.describe()
# Out:
#            Duration         Price   Journey_Day  Journey_Month      Dep_Hour  \
# count  10683.000000  10683.000000  10683.000000   10683.000000  10683.000000
# mean     643.093232   9087.064121     12.682205       5.534775     12.490686
# std      507.862001   4611.359167      8.803701       2.987489      5.748650
# min        5.000000   1759.000000      3.000000       1.000000      0.000000
# 25%      170.000000   5277.000000      5.000000       3.000000      8.000000
# 50%      520.000000   8372.000000      6.000000       5.000000     11.000000
# 75%      930.000000  12373.000000     21.000000       6.000000     18.000000
# max     2860.000000  79512.000000     27.000000      12.000000     23.000000
#
#             Dep_Min  Arrival_Hour   Arrival_Min
# count  10683.000000  10683.000000  10683.000000
# mean      24.411214     13.348778     24.690630
# std       18.767980      6.859125     16.506036
# min        0.000000      0.000000      0.000000
# 25%        5.000000      8.000000     10.000000
# 50%       25.000000     14.000000     25.000000
# 75%       40.000000     19.000000     35.000000
# max       55.000000     23.000000     55.000000

# %% [markdown]
# - `mean > median in duration, price, journey_day, journey_month and dep_hour, implying right skew`
# - `mean < median in dep_min, arrival_hour and arrival_min, impying left skew.`
# - `min price = 1759`
# - `max price = 79512`
# - `avg price = 9087.06`
# - `there is indication of outliers present in price and duration due to large diff between q3 and max`

# %% [markdown]
# ## Data Visualization

# %%
categorical_col = []
for i in df.dtypes.index:
    if df.dtypes[i]=='object':
        categorical_col.append(i) 
print(categorical_col)
# Out:
# ['Airline', 'Source', 'Destination', 'Route', 'Total_Stops', 'Additional_Info']

# %%
numerical_col = []
for i in df.dtypes.index:
    if df.dtypes[i]!='object':
        numerical_col.append(i)
print(numerical_col)
# Out:
# ['Duration', 'Price', 'Journey_Day', 'Journey_Month', 'Dep_Hour', 'Dep_Min', 'Arrival_Hour', 'Arrival_Min']

# %% [markdown]
# `categorical and numerical columns have been identified for the purpose of effective data analysis and visualization`

# %%
plt.figure(figsize=(8,12))
sns.countplot(df["Airline"])
plt.title("Count of flights in different Airlines and Class")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - `Jet Airways has the highest count, followed by IndiGo, Air India, Multiple Carriers and SpiceJet`
# - `low count in Vistara, Air Asia and GoAir`
# - `Very few flights in Vistara Premium economy, Jet Airways Business, Multiple Carriers Premium Economy and Truject`

# %%
plt.figure(figsize=(8,8))
sns.countplot(df["Source"])
plt.title("Different Source Airports")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# `Delhi has the highest numbers, followed by Kolkata and Bangalore`

# %%
plt.figure(figsize=(8,8))
sns.countplot(df["Destination"])
plt.title("Different Desitnation Airports")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# `Cochin has the highest numbers, followed by Bangalore and Delhi`

# %%
plt.figure(figsize=(8,8))
sns.countplot(df["Total_Stops"])
plt.title("Total Stops between Source and Destination")
plt.show()

# %% [markdown]
# `Most flights have 1 stop, followed by non-stop flights and 2 stops`

# %%
# checking for skewness
plt.figure(figsize=(15,15))
plotnumber=1
for col in numerical_col:
    if plotnumber<=8:
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(df[col],color='c')
        plt.xlabel(col,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# `There is skewness in several columns, but none are completely normally distrbuted.`

# %%
plt.figure(figsize=(15,10))
sns.barplot(df['Airline'],df["Price"],data=df)
plt.title("Comparison - Airline and Price")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - `Jet Airways Business has the most expensive tickets and completely stands out`
# - `Out of the others, Jet Airways, Multiple Carriers, Multiple Carriers Premium Economy and Air India have expensive tickets`

# %%
plt.figure(figsize=(8,6))
sns.barplot(df["Source"],df["Price"],data=df)
plt.title("Comparison - Source and Price")
plt.show()

# %% [markdown]
# `Flights originating from Delhi are most expensive, followed by those from Kolkata and Bangalore, and then Mumbai and Chennai`

# %%
plt.figure(figsize=(8,6))
sns.barplot(df["Destination"],df["Price"],data=df)
plt.title("Comparison - Destination and Price")
plt.show()

# %% [markdown]
# `Flights with destination of Cochin are most expensive, followed by Bangalore and Delhi, and then Hyderabad and Kolkata`

# %%
plt.figure(figsize=(8,6))
sns.barplot(df["Total_Stops"],df["Price"],data=df)
plt.title("Comparison - Total Stops and Price")
plt.show()

# %% [markdown]
# `we can see that flight prices increase with number of stops - with non-stop flights being the cheapest and flights with 4 stops being the most expensive`

# %%
fig, axes = plt.subplots(2,2,figsize=(12,12))

sns.boxplot(x='Journey_Day',y='Price',ax = axes[0,0],data=df)
sns.barplot(x='Journey_Month',y='Price',ax = axes[0,1],data=df)
sns.boxplot(x='Dep_Min',y='Price',ax=axes[1,0],data=df)
sns.barplot(x='Dep_Hour',y='Price',ax=axes[1,1],data=df)
# Out:
# <AxesSubplot:xlabel='Dep_Hour', ylabel='Price'>

# %% [markdown]
# - `flights on the 3rd of the month appear to be most expensive`
# - `flights are cheapest in April and most expensive in January`
# - `Dep_Min does not show any relevant insights`
# - `Flights leaving around 1 am are apparently cheaper, followed by those departing at midnight, 5 am and 3 pm`

# %%
plt.figure(figsize=(8,8))
sns.stripplot(x=df['Airline'],y=df['Price'],hue=df["Destination"])
plt.title("Comparison - Airline and Price on the basis of Destination")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# `Jet Airways flights to Delhi appear to be very expensive, and most multiple carriers are heading to Cochin`

# %%
sns.pairplot(df,hue="Price")
plt.show()

# %% [markdown]
# - `shows the relationship of price with all features`
# - `skewness is evident on the diagonal`
# - `linear relationships between features are also evident`

# %% [markdown]
# ## Outlier Check

# %%
plt.figure(figsize=(15,15))
plotnumber=1
for col in numerical_col:
    if plotnumber<=8:
        ax = plt.subplot(3,3,plotnumber)
        sns.boxplot(df[col],color="c")
        plt.xlabel(col,fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# - `Outliers present in Duration, Price and Journey_Month`
# - `Need to remove the outliers from Duration and Journey_Month using z score`

# %%
features = df[["Duration","Journey_Month"]]
z = np.abs(zscore(features))
z
# Out:
# array([[0.93158255, 0.84850298],
#        [0.39007152, 1.5179928 ],
#        [0.97847452, 1.15996647],
#        ...,
#        [0.91189124, 0.51375808],
#        [0.95127386, 1.5179928 ],
#        [0.28176932, 1.15996647]])

# %%
new_df = df[(z<3).all(axis=1)]
new_df
# Out:
#            Airline    Source Destination                  Route  Duration  \
# 0           IndiGo  Banglore       Delhi              BLR → DEL       170
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR       445
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      1140
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR       325
# 4           IndiGo  Banglore       Delhi        BLR → NAG → DEL       285
# ...            ...       ...         ...                    ...       ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR       150
# 10679    Air India   Kolkata    Banglore              CCU → BLR       155
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL       180
# 10681      Vistara  Banglore       Delhi              BLR → DEL       160
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK       500
#
#       Total_Stops Additional_Info  Price  Journey_Day  Journey_Month  \
# 0        non-stop         No Info   3897           24              3
# 1         2 stops         No Info   7662            5              1
# 2         2 stops         No Info  13882            6              9
# 3          1 stop         No Info   6218            5             12
# 4          1 stop         No Info  13302            3              1
# ...           ...             ...    ...          ...            ...
# 10678    non-stop         No Info   4107            4              9
# 10679    non-stop         No Info   4145           27              4
# 10680    non-stop         No Info   7229           27              4
# 10681    non-stop         No Info  12648            3              1
# 10682     2 stops         No Info  11753            5              9
#
#        Dep_Hour  Dep_Min  Arrival_Hour  Arrival_Min
# 0            22       20             1           10
# 1             5       50            13           15
# 2             9       25             4           25
# 3            18        5            23           30
# 4            16       50            21           35
# ...         ...      ...           ...          ...
# 10678        19       55            22           25
# 10679        20       45            23           20
# 10680         8       20            11           20
# 10681        11       30            14           10
# 10682        10       55            19           15
#
# [10617 rows x 14 columns]

# %%
print(df.shape)
print(new_df.shape)
# Out:
# (10683, 14)
# (10617, 14)

# %%
loss = (10683-10617)/10683*100
loss
# Out:
# 0.6178039876439202

# %% [markdown]
# `Data loss is very minimal and therefore acceptable`

# %% [markdown]
# ## Skewness Check

# %%
new_df.skew()
# Out:
# Duration         0.774266
# Price            1.824502
# Journey_Day      0.367029
# Journey_Month    0.628224
# Dep_Hour         0.103798
# Dep_Min          0.164551
# Arrival_Hour    -0.361250
# Arrival_Min      0.107805
# dtype: float64

# %% [markdown]
# `Again, Duration and Journey_Month have skewness, which needs to be removed`

# %%
new_df['Duration'] = np.log1p(new_df['Duration'])

# %%
new_df['Journey_Month'] = np.log1p(new_df['Journey_Month'])

# %%
new_df.skew()
# Out:
# Duration        -0.178335
# Price            1.824502
# Journey_Day      0.367029
# Journey_Month   -0.533689
# Dep_Hour         0.103798
# Dep_Min          0.164551
# Arrival_Hour    -0.361250
# Arrival_Min      0.107805
# dtype: float64

# %% [markdown]
# `Skewness has been removed from Duration and Journey_Month`

# %% [markdown]
# ## Label Encoding

# %%
categorical_col
# Out:
# ['Airline', 'Source', 'Destination', 'Route', 'Total_Stops', 'Additional_Info']

# %%
lbl = LabelEncoder()
new_df[categorical_col]=new_df[categorical_col].apply(lbl.fit_transform)
new_df
# Out:
#        Airline  Source  Destination  Route  Duration  Total_Stops  \
# 0            3       0            2     18  5.141664            4
# 1            1       3            0     84  6.100319            1
# 2            4       2            1    118  7.039660            1
# 3            3       3            0     91  5.786897            0
# 4            3       0            2     29  5.655992            0
# ...        ...     ...          ...    ...       ...          ...
# 10678        0       3            0     64  5.017280            4
# 10679        1       3            0     64  5.049856            4
# 10680        4       0            2     18  5.198497            4
# 10681       10       0            2     18  5.081404            4
# 10682        1       2            1    108  6.216606            1
#
#        Additional_Info  Price  Journey_Day  Journey_Month  Dep_Hour  Dep_Min  \
# 0                    6   3897           24       1.386294        22       20
# 1                    6   7662            5       0.693147         5       50
# 2                    6  13882            6       2.302585         9       25
# 3                    6   6218            5       2.564949        18        5
# 4                    6  13302            3       0.693147        16       50
# ...                ...    ...          ...            ...       ...      ...
# 10678                6   4107            4       2.302585        19       55
# 10679                6   4145           27       1.609438        20       45
# 10680                6   7229           27       1.609438         8       20
# 10681                6  12648            3       0.693147        11       30
# 10682                6  11753            5       2.302585        10       55
#
#        Arrival_Hour  Arrival_Min
# 0                 1           10
# 1                13           15
# 2                 4           25
# 3                23           30
# 4                21           35
# ...             ...          ...
# 10678            22           25
# 10679            23           20
# 10680            11           20
# 10681            14           10
# 10682            19           15
#
# [10617 rows x 14 columns]

# %% [markdown]
# `All categorical information has been encoded into numerical information`

# %% [markdown]
# ## Establishing correlations

# %%
corr = new_df.corr()
corr
# Out:
#                   Airline    Source  Destination     Route  Duration  \
# Airline          1.000000 -0.013644     0.070721  0.028401 -0.122143
# Source          -0.013644  1.000000    -0.434677  0.404009  0.122739
# Destination      0.070721 -0.434677     1.000000 -0.230755 -0.509154
# Route            0.028401  0.404009    -0.230755  1.000000  0.368475
# Duration        -0.122143  0.122739    -0.509154  0.368475  1.000000
# Total_Stops      0.035669 -0.225922     0.510659 -0.439372 -0.809980
# Additional_Info  0.092783  0.008129     0.093871  0.029469 -0.254019
# Price           -0.036874  0.016718    -0.263334  0.163635  0.605786
# Journey_Day      0.030219  0.007158     0.007309  0.096042 -0.042848
# Journey_Month   -0.001278  0.062011    -0.061873  0.076196  0.061807
# Dep_Hour        -0.041977  0.059469    -0.088810 -0.070005 -0.001689
# Dep_Min         -0.061477 -0.055929     0.097052 -0.066420 -0.033797
# Arrival_Hour    -0.002555  0.026144    -0.058190  0.011514  0.056730
# Arrival_Min     -0.073921  0.021640     0.006954 -0.174071 -0.125315
#
#                  Total_Stops  Additional_Info     Price  Journey_Day  \
# Airline             0.035669         0.092783 -0.036874     0.030219
# Source             -0.225922         0.008129  0.016718     0.007158
# Destination         0.510659         0.093871 -0.263334     0.007309
# Route              -0.439372         0.029469  0.163635     0.096042
# Duration           -0.809980        -0.254019  0.605786    -0.042848
# Total_Stops         1.000000         0.242302 -0.572413     0.043711
# Additional_Info     0.242302         1.000000 -0.193478     0.018760
# Price              -0.572413        -0.193478  1.000000    -0.163765
# Journey_Day         0.043711         0.018760 -0.163765     1.000000
# Journey_Month      -0.048791         0.020064 -0.013511    -0.097582
# Dep_Hour            0.038512        -0.042549  0.011430    -0.002628
# Dep_Min             0.049105         0.001786 -0.025585    -0.017421
# Arrival_Hour       -0.095213        -0.020098  0.021107    -0.001501
# Arrival_Min         0.176915         0.030347 -0.088909    -0.021901
#
#                  Journey_Month  Dep_Hour   Dep_Min  Arrival_Hour  Arrival_Min
# Airline              -0.001278 -0.041977 -0.061477     -0.002555    -0.073921
# Source                0.062011  0.059469 -0.055929      0.026144     0.021640
# Destination          -0.061873 -0.088810  0.097052     -0.058190     0.006954
# Route                 0.076196 -0.070005 -0.066420      0.011514    -0.174071
# Duration              0.061807 -0.001689 -0.033797      0.056730    -0.125315
# Total_Stops          -0.048791  0.038512  0.049105     -0.095213     0.176915
# Additional_Info       0.020064 -0.042549  0.001786     -0.020098     0.030347
# Price                -0.013511  0.011430 -0.025585      0.021107    -0.088909
# Journey_Day          -0.097582 -0.002628 -0.017421     -0.001501    -0.021901
# Journey_Month         1.000000  0.020587 -0.005264     -0.005743    -0.031453
# Dep_Hour              0.020587  1.000000 -0.026077      0.010967     0.068350
# Dep_Min              -0.005264 -0.026077  1.000000      0.043613    -0.018693
# Arrival_Hour         -0.005743  0.010967  0.043613      1.000000    -0.155330
# Arrival_Min          -0.031453  0.068350 -0.018693     -0.155330     1.000000

# %%
plt.figure(figsize=(20,15))
sns.heatmap(new_df.corr(),linewidths=.1,fmt=".1g",annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# - `Duration is highly positively correlated with the target variable`
# - `Total Stops is highly negatively correlated with the target variable`

# %%
corr["Price"].sort_values(ascending=False)
# Out:
# Price              1.000000
# Duration           0.605786
# Route              0.163635
# Arrival_Hour       0.021107
# Source             0.016718
# Dep_Hour           0.011430
# Journey_Month     -0.013511
# Dep_Min           -0.025585
# Airline           -0.036874
# Arrival_Min       -0.088909
# Journey_Day       -0.163765
# Additional_Info   -0.193478
# Destination       -0.263334
# Total_Stops       -0.572413
# Name: Price, dtype: float64

# %%
plt.figure(figsize=(15,10))
new_df.corr()["Price"].sort_values(ascending=False).drop(["Price"]).plot(kind="bar",color="c")
plt.xlabel('Features',fontsize=15)
plt.ylabel('Target',fontsize=15)
plt.title('Correlation between Target and Features')
plt.show()

# %% [markdown]
# - `Duration and Total Stops are highly correlated to Price`
# - `Departure Hour and Month of Journey have very low correlation with price`

# %% [markdown]
# ## Feature Scaling

# %%
x = new_df.drop("Price",axis=1)
y = new_df["Price"]

# %%
x.shape
# Out:
# (10617, 13)

# %%
y.shape
# Out:
# (10617,)

# %%
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#         Airline    Source  Destination     Route  Duration  Total_Stops  \
# 0     -0.416258 -1.655042     0.812707 -1.544003 -1.058285     1.402360
# 1     -1.266881  0.888124    -1.157048  0.254498  0.007344    -0.253797
# 2      0.009053  0.040402    -0.172170  1.180998  1.051504    -0.253797
# 3     -0.416258  0.888124    -1.157048  0.445248 -0.341051    -0.805850
# 4     -0.416258 -1.655042     0.812707 -1.244253 -0.486564    -0.805850
# ...         ...       ...          ...       ...       ...          ...
# 10612 -1.692192  0.888124    -1.157048 -0.290502 -1.196549     1.402360
# 10613 -1.266881  0.888124    -1.157048 -0.290502 -1.160337     1.402360
# 10614  0.009053 -1.655042     0.812707 -1.544003 -0.995110     1.402360
# 10615  2.560922 -1.655042     0.812707 -1.544003 -1.125269     1.402360
# 10616 -1.266881  0.040402    -0.172170  0.908498  0.136608    -0.253797
#
#        Additional_Info  Journey_Day  Journey_Month  Dep_Hour   Dep_Min  \
# 0             0.331561     1.286176      -0.754967  1.649475 -0.235894
# 1             0.331561    -0.873920      -2.141814 -1.312186  1.362715
# 2             0.331561    -0.760231       1.078344 -0.615325  0.030541
# 3             0.331561    -0.873920       1.603281  0.952614 -1.035199
# 4             0.331561    -1.101299      -2.141814  0.604183  1.362715
# ...                ...          ...            ...       ...       ...
# 10612         0.331561    -0.987609       1.078344  1.126829  1.629150
# 10613         0.331561     1.627244      -0.308502  1.301044  1.096280
# 10614         0.331561     1.627244      -0.308502 -0.789540 -0.235894
# 10615         0.331561    -1.101299      -2.141814 -0.266894  0.296976
# 10616         0.331561    -0.873920       1.078344 -0.441109  1.629150
#
#        Arrival_Hour  Arrival_Min
# 0         -1.794784    -0.889208
# 1         -0.046050    -0.586465
# 2         -1.357601     0.019019
# 3          1.411228     0.321762
# 4          1.119772     0.624504
# ...             ...          ...
# 10612      1.265500     0.019019
# 10613      1.411228    -0.283723
# 10614     -0.337506    -0.283723
# 10615      0.099677    -0.889208
# 10616      0.828317    -0.586465
#
# [10617 rows x 13 columns]

# %% [markdown]
# `Bias has been removed using Standard Scaler`

# %% [markdown]
# ## VIF

# %%
vif = pd.DataFrame()
vif["VIF Values"] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features'] = x.columns
vif
# Out:
#     VIF Values         Features
# 0     1.047185          Airline
# 1     1.526467           Source
# 2     1.775435      Destination
# 3     1.568247            Route
# 4     3.303510         Duration
# 5     3.400398      Total_Stops
# 6     1.113860  Additional_Info
# 7     1.033612      Journey_Day
# 8     1.022385    Journey_Month
# 9     1.031386         Dep_Hour
# 10    1.020644          Dep_Min
# 11    1.037504     Arrival_Hour
# 12    1.095064      Arrival_Min

# %% [markdown]
# `All features have VIF less than 10, so no problem of multicollinearity`

# %%
pca = PCA()
pr_comp = pca.fit_transform(x)
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Variance %')
plt.title('Explained Variance')
plt.show()

# %% [markdown]
# ## Model Building

# %% [markdown]
# `Finding best random state`

# %%
maxAccu = 0
maxRS = 0
for i in range(1,100):
    x_train,x_test,y_train,y_test = TTS(x,y,test_size=0.30,random_state=i)
    mod = RandomForestRegressor()
    mod.fit(x_train,y_train)
    pred = mod.predict(x_test)
    acc = r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRs = i
print("Maximum r2_score is ",maxAccu,"at random_state",maxRS)
# Out:
# Maximum r2_score is  0.9061600435180165 at random_state 0

# %%
x_train,x_test,y_train,y_test = TTS(x,y,test_size=0.30,random_state=maxRS)

# %%
lr = LinearRegression()
rf = RandomForestRegressor()
svr = SVR()
dt = DecisionTreeRegressor()

# %%
lr.fit(x_train,y_train)
rf.fit(x_train,y_train)
svr.fit(x_train,y_train)
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
print("-"*50)
print("Linear Regression Model")
print("-"*50)
lr_pred = lr.predict(x_test)
print("R2 Score: ", r2_score(y_test,lr_pred), "\n")
print("Mean Squared Error: ", mean_squared_error(y_test,lr_pred), "\n"*2)

print("-"*50)
print("Random Forest Model")
print("-"*50)
rf_pred = rf.predict(x_test)
print("R2 Score: ", r2_score(y_test,rf_pred), "\n")
print("Mean Squared Error: ", mean_squared_error(y_test,rf_pred), "\n"*2)

print("-"*50)
print("Support Vector Regression Model")
print("-"*50)
svr_pred = svr.predict(x_test)
print("R2 Score: ", r2_score(y_test,svr_pred), "\n")
print("Mean Squared Error: ", mean_squared_error(y_test,svr_pred), "\n"*2)

print("-"*50)
print("Decision Tree Model")
print("-"*50)
dt_pred = dt.predict(x_test)
print("R2 Score: ", r2_score(y_test,dt_pred), "\n")
print("Mean Squared Error: ", mean_squared_error(y_test,dt_pred), "\n"*2)
# Out:
# --------------------------------------------------
# Linear Regression Model
# --------------------------------------------------
# R2 Score:  0.4406800249108862
#
# Mean Squared Error:  11594262.45129725
#
#
# --------------------------------------------------
# Random Forest Model
# --------------------------------------------------
# R2 Score:  0.8880254875519417
#
# Mean Squared Error:  2321143.4295225968
#
#
# --------------------------------------------------
# Support Vector Regression Model
# --------------------------------------------------
# R2 Score:  0.041282537585365375
#
# Mean Squared Error:  19873457.718197852
#
#
# --------------------------------------------------
# Decision Tree Model
# --------------------------------------------------
# R2 Score:  0.8143785721906756
#
# Mean Squared Error:  3847785.965918602

# %%
sns.regplot(y_test,lr_pred,color='c')
plt.show()

# %%
sns.regplot(y_test,rf_pred,color='c')
plt.show()

# %%
sns.regplot(y_test,svr_pred,color='c')
plt.show()

# %%
sns.regplot(y_test,dt_pred,color='c')
plt.show()

# %%
print("Cross Validation Score for Linear Regression Model: ", cross_val_score(lr,x,y,cv=5).mean(), "\n"*2)
print("Cross Validation Score for Random Forest Model: ", cross_val_score(rf,x,y,cv=5).mean(), "\n"*2)
print("Cross Validation Score for Support Vector Regression Model: ", cross_val_score(svr,x,y,cv=5).mean(), "\n"*2)
print("Cross Validation Score for Decision Tree Model: ", cross_val_score(dt,x,y,cv=5).mean(), "\n"*2)
# Out:
# Cross Validation Score for Linear Regression Model:  0.42237386719716613
#
#
# Cross Validation Score for Random Forest Model:  0.8743770221635747
#
#
# Cross Validation Score for Support Vector Regression Model:  0.04168539927171104
#
#
# Cross Validation Score for Decision Tree Model:  0.7853350881499577

# %% [markdown]
# #### It appears `Random Forest` is the best model for our prediction.

# %% [markdown]
# ## Hyperparameter Tuning

# %%
parameters = {'n_estimators':[10,50,100],
              'max_depth':[10,20,30],
              'max_features':['auto','sqrt'],
              'min_samples_leaf': [1, 2, 3],
              'min_samples_split': [2, 5, 8]
             }

# %%
GCV = GridSearchCV(RandomForestRegressor(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [10, 20, 30],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [2, 5, 8],
#                          'n_estimators': [10, 50, 100]})

# %%
GCV.best_params_
# Out:
# {'max_depth': 30,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 100}

# %%
Final_model = RandomForestRegressor(max_depth=30, max_features='sqrt', min_samples_leaf=1, min_samples_split=2, n_estimators=100)
Final_model.fit(x_train,y_train)
pred = Final_model.predict(x_test)
print('R2_Score:',r2_score(y_test,pred)*100)
print("RMSE value:",np.sqrt(metrics.mean_squared_error(y_test, pred)))
print('MAE:',metrics.mean_absolute_error(y_test, pred))
print('MSE:',metrics.mean_squared_error(y_test, pred))
# Out:
# R2_Score: 90.21482244628382
# RMSE value: 1424.2156505432908
# MAE: 776.9375271632705
# MSE: 2028390.2192524495

# %% [markdown]
# #### Post hyperparameter tuning, the R2 score has gone from 88.80% to 90.21%.

# %% [markdown]
# ## Saving and relaoding the model for prediction

# %%
joblib.dump(Final_model,'Flight_Price_Prediction.pkl')
# Out:
# ['Flight_Price_Prediction.pkl']

# %%
Model = joblib.load("Flight_Price_Prediction.pkl")

a = np.array(y_test)
predicted = np.array(Model.predict(x_test))
df_com = pd.DataFrame({"Original":a,"Predicted":predicted},index= range(len(a)))
df_com
# Out:
#       Original   Predicted
# 0        17024  15757.5100
# 1         7817   9450.7200
# 2        13376  13412.6100
# 3        14486  10139.6235
# 4        11560  12168.1200
# ...        ...         ...
# 3181     14388  14117.9400
# 3182     10368  10557.8500
# 3183      9899  10335.9100
# 3184     12395  12745.5900
# 3185     10031   9552.0900
#
# [3186 rows x 2 columns]

# %% [markdown]
# # Predicting using Test Data

# %% [markdown]
# ## Preparing the test data for prediction

# %%
test_df = pd.read_excel("Test_set.xlsx")
test_df.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
test_df.shape
# Out:
# (2671, 10)

# %%
test_df['Date_of_Journey'] = pd.to_datetime(test_df['Date_of_Journey'])

# %%
test_df['Dep_Time'] = pd.to_datetime(test_df['Dep_Time'])

# %%
test_df['Arrival_Time']=pd.to_datetime(test_df['Arrival_Time'])

# %%
test_df['Journey_Day'] = pd.to_datetime(test_df.Date_of_Journey,format="%d/%m/%Y").dt.day
test_df['Journey_Month'] = pd.to_datetime(test_df.Date_of_Journey, format="%d/%m/%Y").dt.month

# %%
test_df.drop("Date_of_Journey",axis=1,inplace=True)

# %%
test_df['Duration']=test_df['Duration'].str.replace('h','*60').str.replace(' ','+').str.replace('m','*1').apply(eval)
test_df['Duration']=pd.to_numeric(test_df['Duration'])

# %%
test_df['Dep_Hour']=pd.to_datetime(test_df['Dep_Time']).dt.hour
test_df['Dep_Min']=pd.to_datetime(test_df['Dep_Time']).dt.minute

# %%
test_df.drop("Dep_Time",axis=1,inplace=True)

# %%
test_df['Arrival_Hour']=pd.to_datetime(test_df['Arrival_Time']).dt.hour
test_df['Arrival_Min']=pd.to_datetime(test_df['Arrival_Time']).dt.minute
test_df.drop("Arrival_Time",axis=1,inplace=True)

# %%
test_df["Destination"] = test_df["Destination"].replace("New Delhi","Delhi")
test_df['Additional_Info'] = test_df['Additional_Info'].replace("No info", "No Info")

# %%
df_null_test = test_df[test_df.isna().any(axis=1)]
df_null_test
# Out:
# Empty DataFrame
# Columns: [Airline, Source, Destination, Route, Duration, Total_Stops, Additional_Info, Journey_Day, Journey_Month, Dep_Hour, Dep_Min, Arrival_Hour, Arrival_Min]
# Index: []

# %%
test_df.isnull().sum()
# Out:
# Airline            0
# Source             0
# Destination        0
# Route              0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Journey_Day        0
# Journey_Month      0
# Dep_Hour           0
# Dep_Min            0
# Arrival_Hour       0
# Arrival_Min        0
# dtype: int64

# %%
test_df.describe()
# Out:
#          Duration  Journey_Day  Journey_Month     Dep_Hour      Dep_Min  \
# count  2671.00000  2671.000000    2671.000000  2671.000000  2671.000000
# mean    639.74167    12.026956       5.607263    12.603519    24.891426
# std     502.18693     8.564408       3.042952     5.686673    19.086522
# min       5.00000     3.000000       1.000000     0.000000     0.000000
# 25%     175.00000     5.000000       3.000000     8.000000     5.000000
# 50%     520.00000     6.000000       5.000000    12.000000    25.000000
# 75%     915.00000    21.000000       6.000000    18.000000    45.000000
# max    2440.00000    27.000000      12.000000    23.000000    55.000000
#
#        Arrival_Hour  Arrival_Min
# count   2671.000000  2671.000000
# mean      13.585174    24.558218
# std        7.040396    16.775436
# min        0.000000     0.000000
# 25%        8.000000    10.000000
# 50%       15.000000    25.000000
# 75%       19.000000    35.000000
# max       23.000000    55.000000

# %%
categorical_col=[]
for i in test_df.dtypes.index:
    if test_df.dtypes[i]=='object':
        categorical_col.append(i)
print(categorical_col)
# Out:
# ['Airline', 'Source', 'Destination', 'Route', 'Total_Stops', 'Additional_Info']

# %%
numerical_col=[]
for i in test_df.dtypes.index:
    if test_df.dtypes[i]!='object':
        numerical_col.append(i)
print(numerical_col)
# Out:
# ['Duration', 'Journey_Day', 'Journey_Month', 'Dep_Hour', 'Dep_Min', 'Arrival_Hour', 'Arrival_Min']

# %%
# outlier check
plt.figure(figsize=(15,15))
plotnumber=1
for col in numerical_col:
    if plotnumber<=8:
        ax = plt.subplot(3,3,plotnumber)
        sns.boxplot(test_df[col],color='c')
        plt.xlabel(col,fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %%
features = test_df[["Duration","Journey_Month"]]
z = np.abs(zscore(features))
z
# Out:
# array([[0.03038946, 0.12908857],
#        [0.79615079, 2.10122721],
#        [1.56397015, 0.1996012 ],
#        ...,
#        [0.48744299, 0.12908857],
#        [0.5482219 , 0.12908857],
#        [0.43868042, 0.12908857]])

# %%
new_test_df = test_df[(z<3).all(axis=1)]
new_test_df
# Out:
#                 Airline    Source Destination            Route  Duration  \
# 0           Jet Airways     Delhi      Cochin  DEL → BOM → COK       655
# 1                IndiGo   Kolkata    Banglore  CCU → MAA → BLR       240
# 2           Jet Airways     Delhi      Cochin  DEL → BOM → COK      1425
# 3     Multiple carriers     Delhi      Cochin  DEL → BOM → COK       780
# 4              Air Asia  Banglore       Delhi        BLR → DEL       170
# ...                 ...       ...         ...              ...       ...
# 2666          Air India   Kolkata    Banglore  CCU → DEL → BLR      1435
# 2667             IndiGo   Kolkata    Banglore        CCU → BLR       155
# 2668        Jet Airways     Delhi      Cochin  DEL → BOM → COK       395
# 2669          Air India     Delhi      Cochin  DEL → BOM → COK       915
# 2670  Multiple carriers     Delhi      Cochin  DEL → BOM → COK       860
#
#      Total_Stops              Additional_Info  Journey_Day  Journey_Month  \
# 0         1 stop                      No Info            6              6
# 1         1 stop                      No Info            5             12
# 2         1 stop  In-flight meal not included           21              5
# 3         1 stop                      No Info           21              5
# 4       non-stop                      No Info           24              6
# ...          ...                          ...          ...            ...
# 2666      1 stop                      No Info            6              6
# 2667    non-stop                      No Info           27              3
# 2668      1 stop                      No Info            3              6
# 2669      1 stop                      No Info            3              6
# 2670      1 stop                      No Info           15              6
#
#       Dep_Hour  Dep_Min  Arrival_Hour  Arrival_Min
# 0           17       30             4           25
# 1            6       20            10           20
# 2           19       15            19            0
# 3            8        0            21            0
# 4           23       55             2           45
# ...        ...      ...           ...          ...
# 2666        20       30            20           25
# 2667        14       20            16           55
# 2668        21       50             4           25
# 2669         4        0            19           15
# 2670         4       55            19           15
#
# [2653 rows x 13 columns]

# %%
test_df.shape
# Out:
# (2671, 13)

# %%
new_test_df.shape
# Out:
# (2653, 13)

# %%
loss = (2671-2653)/2671*100
loss
# Out:
# 0.6739049045301385

# %%
# skewness check
new_test_df.skew()
# Out:
# Duration         0.809826
# Journey_Day      0.475210
# Journey_Month    0.591565
# Dep_Hour         0.083357
# Dep_Min          0.132681
# Arrival_Hour    -0.432551
# Arrival_Min      0.110111
# dtype: float64

# %%
new_test_df["Duration"]=np.log1p(new_test_df["Duration"])
new_test_df["Journey_Month"]=np.log1p(new_test_df["Journey_Month"])

# %%
new_test_df.skew()
# Out:
# Duration        -0.229080
# Journey_Day      0.475210
# Journey_Month   -0.541053
# Dep_Hour         0.083357
# Dep_Min          0.132681
# Arrival_Hour    -0.432551
# Arrival_Min      0.110111
# dtype: float64

# %%
# label encoding
LE=LabelEncoder()
new_test_df[categorical_col]= new_test_df[categorical_col].apply(LE.fit_transform)
new_test_df
# Out:
#       Airline  Source  Destination  Route  Duration  Total_Stops  \
# 0           4       2            1     76  6.486161            0
# 1           3       3            0     65  5.484797            0
# 2           4       2            1     76  7.262629            0
# 3           6       2            1     76  6.660575            0
# 4           0       0            2     16  5.141664            4
# ...       ...     ...          ...    ...       ...          ...
# 2666        1       3            0     51  7.269617            0
# 2667        3       3            0     43  5.049856            4
# 2668        4       2            1     76  5.981414            0
# 2669        1       2            1     76  6.820016            0
# 2670        6       2            1     76  6.758095            0
#
#       Additional_Info  Journey_Day  Journey_Month  Dep_Hour  Dep_Min  \
# 0                   4            6       1.945910        17       30
# 1                   4            5       2.564949         6       20
# 2                   3           21       1.791759        19       15
# 3                   4           21       1.791759         8        0
# 4                   4           24       1.945910        23       55
# ...               ...          ...            ...       ...      ...
# 2666                4            6       1.945910        20       30
# 2667                4           27       1.386294        14       20
# 2668                4            3       1.945910        21       50
# 2669                4            3       1.945910         4        0
# 2670                4           15       1.945910         4       55
#
#       Arrival_Hour  Arrival_Min
# 0                4           25
# 1               10           20
# 2               19            0
# 3               21            0
# 4                2           45
# ...            ...          ...
# 2666            20           25
# 2667            16           55
# 2668             4           25
# 2669            19           15
# 2670            19           15
#
# [2653 rows x 13 columns]

# %%
# feature scaling
scaler = StandardScaler()
new_test_df = pd.DataFrame(scaler.fit_transform(new_test_df),columns=new_test_df.columns)
new_test_df
# Out:
#        Airline    Source  Destination     Route  Duration  Total_Stops  \
# 0     0.004605  0.031440    -0.167242  0.804966  0.438880    -0.791072
# 1    -0.431683  0.873978    -1.175634  0.398570 -0.681421    -0.791072
# 2     0.004605  0.031440    -0.167242  0.804966  1.307572    -0.791072
# 3     0.877180  0.031440    -0.167242  0.804966  0.634010    -0.791072
# 4    -1.740546 -1.653635     0.841150 -1.411740 -1.065309     1.429790
# ...        ...       ...          ...       ...       ...          ...
# 2648 -1.304259  0.873978    -1.175634 -0.118662  1.315390    -0.791072
# 2649 -0.431683  0.873978    -1.175634 -0.414222 -1.168021     1.429790
# 2650  0.004605  0.031440    -0.167242  0.804966 -0.125818    -0.791072
# 2651 -1.304259  0.031440    -0.167242  0.804966  0.812389    -0.791072
# 2652  0.877180  0.031440    -0.167242  0.804966  0.743112    -0.791072
#
#       Additional_Info  Journey_Day  Journey_Month  Dep_Hour   Dep_Min  \
# 0            0.327568    -0.706193       0.344970  0.766320  0.272445
# 1            0.327568    -0.823069       1.565339 -1.172433 -0.252462
# 2           -1.989868     1.046954       0.041078  1.118821 -0.514916
# 3            0.327568     1.046954       0.041078 -0.819933 -1.302277
# 4            0.327568     1.397583       0.344970  1.823822  1.584714
# ...               ...          ...            ...       ...       ...
# 2648         0.327568    -0.706193       0.344970  1.295071  0.272445
# 2649         0.327568     1.748212      -0.758252  0.237569 -0.252462
# 2650         0.327568    -1.056822       0.344970  1.471321  1.322260
# 2651         0.327568    -1.056822       0.344970 -1.524934 -1.302277
# 2652         0.327568     0.345695       0.344970 -1.524934  1.584714
#
#       Arrival_Hour  Arrival_Min
# 0        -1.354818     0.025591
# 1        -0.503215    -0.272182
# 2         0.774190    -1.463273
# 3         1.058057    -1.463273
# 4        -1.638686     1.216682
# ...            ...          ...
# 2648      0.916123     0.025591
# 2649      0.348388     1.812227
# 2650     -1.354818     0.025591
# 2651      0.774190    -0.569955
# 2652      0.774190    -0.569955
#
# [2653 rows x 13 columns]

# %% [markdown]
# ## Predicting the flight price

# %%
Predicted_Price = Model.predict(new_test_df)
Predicted_Price
# Out:
# array([14115.15,  4234.28, 12616.49, ..., 15612.77, 13278.92,  7623.22])

# %%
Prediction = pd.DataFrame()
Prediction['Price'] = Predicted_Price
Prediction
# Out:
#              Price
# 0     14115.150000
# 1      4234.280000
# 2     12616.490000
# 3     10547.818333
# 4      3933.620000
# ...            ...
# 2648  10244.580000
# 2649   5558.000000
# 2650  15612.770000
# 2651  13278.920000
# 2652   7623.220000
#
# [2653 rows x 1 columns]

# %%
Prediction.to_csv("Flight_Price_Prediction_TestData.csv",index=False)

# %% [markdown]
# # `END`
